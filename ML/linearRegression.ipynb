# %%
import pandas as pd

try: 
    df_ah = pd.read_excel("./AmesHousing.xlsx", header=None)
    df_ah

except Exception as e:
    print(f"Error with reading Excel: {e}")
# Out:
# Error with reading Excel: `Import openpyxl` failed.  Use pip or conda to install the openpyxl package.
